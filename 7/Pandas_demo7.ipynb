# %%
import pandas as pd

fpath = 'tianqi.csv'

# %%
df = pd.read_csv(fpath)

# %%
df
# Out:
#            YMD bWendu yWendu Tianqi Fengxiang Fengli  aqi aqiinfo  aqiLevel
# 0    1/01/2018    3°C  -12°C      晴       东北风   1-2级   43       优         1
# 1    2/01/2018    6°C   -4°C   阴-多云        东风   1-3级   56       良         2
# 2    3/01/2018    4°C  -21°C   晴-多云        北风     3级   13       优         1
# 3    4/01/2018    9°C  -13°C     多云       东南风   2-3级   67       良         2
# 4    5/01/2018    3°C   -6°C      阴        南风     2级   54       良         2
# ..         ...    ...    ...    ...       ...    ...  ...     ...       ...
# 75  17/03/2018   20°C   -9°C     多云       东北风     1级   67       良         2
# 76  18/03/2018   19°C    1°C      晴       东北风   1-2级   54       良         2
# 77  19/03/2018   19°C    1°C      晴        东风   1-2级   63       良         2
# 78  20/03/2018   29°C    7°C   阴-多云        北风   1-3级  344       差         4
# 79  21/03/2018   17°C  -10°C   晴-多云       东南风     3级   79       良         2
#
# [80 rows x 9 columns]

# %%
df.loc[:,'bWendu'] = df['bWendu'].str.replace('°C','').astype('int32')
df.loc[:,'yWendu'] = df['yWendu'].str.replace('°C','').astype('int32')
# Out:
# C:\Users\Osy\AppData\Local\Temp\ipykernel_13952\3600642768.py:1: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:,'bWendu'] = df['bWendu'].str.replace('°C','').astype('int32')
# C:\Users\Osy\AppData\Local\Temp\ipykernel_13952\3600642768.py:2: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:,'yWendu'] = df['yWendu'].str.replace('°C','').astype('int32')

# %%
df
# Out:
#            YMD  bWendu  yWendu Tianqi Fengxiang Fengli  aqi aqiinfo  aqiLevel
# 0    1/01/2018       3     -12      晴       东北风   1-2级   43       优         1
# 1    2/01/2018       6      -4   阴-多云        东风   1-3级   56       良         2
# 2    3/01/2018       4     -21   晴-多云        北风     3级   13       优         1
# 3    4/01/2018       9     -13     多云       东南风   2-3级   67       良         2
# 4    5/01/2018       3      -6      阴        南风     2级   54       良         2
# ..         ...     ...     ...    ...       ...    ...  ...     ...       ...
# 75  17/03/2018      20      -9     多云       东北风     1级   67       良         2
# 76  18/03/2018      19       1      晴       东北风   1-2级   54       良         2
# 77  19/03/2018      19       1      晴        东风   1-2级   63       良         2
# 78  20/03/2018      29       7   阴-多云        北风   1-3级  344       差         4
# 79  21/03/2018      17     -10   晴-多云       东南风     3级   79       良         2
#
# [80 rows x 9 columns]

# %%
df['aqi'].sort_values(ascending=False)
#sorting a single column
# Out:
# 78    344
# 79     79
# 10     67
# 36     67
# 27     67
#      ...
# 41     13
# 55     13
# 65     13
# 48     13
# 16     13
# Name: aqi, Length: 80, dtype: int64

# %%
#sorting a data frame
df.sort_values(by='aqi',ascending=False)
# Out:
#            YMD  bWendu  yWendu Tianqi Fengxiang Fengli  aqi aqiinfo  aqiLevel
# 78  20/03/2018      29       7   阴-多云        北风   1-3级  344       差         4
# 79  21/03/2018      17     -10   晴-多云       东南风     3级   79       良         2
# 10  11/01/2018      16      -6     多云       东南风   2-3级   67       良         2
# 36   6/02/2018      25      -1   阴-多云        东风   1-3级   67       良         2
# 27  28/01/2018      27       4      晴       东北风   1-2级   67       良         2
# ..         ...     ...     ...    ...       ...    ...  ...     ...       ...
# 41  11/02/2018      19       2      晴        东风   1-2级   13       优         1
# 55  25/02/2018      21      -3      晴        东风   1-2级   13       优         1
# 65   7/03/2018      16      -4   晴-多云        北风     3级   13       优         1
# 48  18/02/2018      24       0      晴       东北风   1-2级   13       优         1
# 16  17/01/2018      10       6   晴-多云        北风     3级   13       优         1
#
# [80 rows x 9 columns]

# %%
#sorting a data frame, by multiple columns
df.sort_values(by = ['aqi','yWendu'], ascending=[False,True])
# Out:
#            YMD  bWendu  yWendu Tianqi Fengxiang Fengli  aqi aqiinfo  aqiLevel
# 78  20/03/2018      29       7   阴-多云        北风   1-3级  344       差         4
# 79  21/03/2018      17     -10   晴-多云       东南风     3级   79       良         2
# 3    4/01/2018       9     -13     多云       东南风   2-3级   67       良         2
# 75  17/03/2018      20      -9     多云       东北风     1级   67       良         2
# 10  11/01/2018      16      -6     多云       东南风   2-3级   67       良         2
# ..         ...     ...     ...    ...       ...    ...  ...     ...       ...
# 48  18/02/2018      24       0      晴       东北风   1-2级   13       优         1
# 41  11/02/2018      19       2      晴        东风   1-2级   13       优         1
# 9   10/01/2018      20       5   晴-多云        北风     3级   13       优         1
# 16  17/01/2018      10       6   晴-多云        北风     3级   13       优         1
# 35   5/02/2018      14       9      晴       东北风   1-2级   13       优         1
#
# [80 rows x 9 columns]
