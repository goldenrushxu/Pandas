# %% [markdown]
# <img src = 'Pandas-one-to-one-merge.JPG' />

# %%
import pandas as pd

# %%
left = pd.DataFrame({'sno':[11,12,13,14],
                    'name':['name_a','name_b','name_c','name_d']}
)
left
# Out:
#    sno    name
# 0   11  name_a
# 1   12  name_b
# 2   13  name_c
# 3   14  name_d

# %%
right = pd.DataFrame({'sno':[11,12,13,14],
                    'age':['21','22','23','24']}
)
right
# Out:
#    sno age
# 0   11  21
# 1   12  22
# 2   13  23
# 3   14  24

# %%
pd.merge(left, right, on = 'sno')
# Out:
#    sno    name age
# 0   11  name_a  21
# 1   12  name_b  22
# 2   13  name_c  23
# 3   14  name_d  24

# %% [markdown]
# <img src ='Pandas-one-to-many-merge.JPG'/>

# %%
right = pd.DataFrame({'sno':[11,11,11,12,12,13],
                    'grade':['语文88','数学57','英语84','语文98','数学76','语文65']}
)
right
# Out:
#    sno grade
# 0   11  语文88
# 1   11  数学57
# 2   11  英语84
# 3   12  语文98
# 4   12  数学76
# 5   13  语文65

# %%
pd.merge(left, right, on = 'sno')
# Out:
#    sno    name grade
# 0   11  name_a  语文88
# 1   11  name_a  数学57
# 2   11  name_a  英语84
# 3   12  name_b  语文98
# 4   12  name_b  数学76
# 5   13  name_c  语文65

# %% [markdown]
# <img src = 'Pandas-many-to-many-merge.JPG'/>

# %%
left = pd.DataFrame ({'sno':[11,11,12,13],
                    'hobby':['篮球','足球','乒乓球','羽毛球']}
)
left
# left.loc(left['sno']==11)
# Out:
#    sno hobby
# 0   11    篮球
# 1   11    足球
# 2   12   乒乓球
# 3   13   羽毛球

# %%
pd.merge(left, right, on='sno')
# Out:
#    sno hobby grade
# 0   11    篮球  语文88
# 1   11    篮球  数学57
# 2   11    篮球  英语84
# 3   11    足球  语文88
# 4   11    足球  数学57
# 5   11    足球  英语84
# 6   12   乒乓球  语文98
# 7   12   乒乓球  数学76
# 8   13   羽毛球  语文65

# %% [markdown]
# <img src = 'Pandas-join.JPG'/>

# %%
left = pd.DataFrame({'key':['K0','K1','K2','K3'],
                    'A':['A0','A1','A2','A3'],
                    'B':['B0','B1','B2','B3']}
)
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right = pd.DataFrame({'key':['K0','K1','K4','K5'],
                    'A':['A10','A11','A12','A13'],
                    'D':['B10','B11','B12','B13']}
)
right
# Out:
#   key    A    D
# 0  K0  A10  B10
# 1  K1  A11  B11
# 2  K4  A12  B12
# 3  K5  A13  B13

# %%
pd.merge(left, right, how = 'left')
# Out:
#   key   A   B    D
# 0  K0  A0  B0  NaN
# 1  K1  A1  B1  NaN
# 2  K2  A2  B2  NaN
# 3  K3  A3  B3  NaN

# %%
pd.merge(left, right, how = 'right')
# Out:
#   key    A    B    D
# 0  K0  A10  NaN  B10
# 1  K1  A11  NaN  B11
# 2  K4  A12  NaN  B12
# 3  K5  A13  NaN  B13

# %%
pd.merge(left, right, how = 'inner')
# Out:
# Empty DataFrame
# Columns: [key, A, B, D]
# Index: []

# %%
pd.merge(left, right, how = 'outer')
# Out:
#   key    A    B    D
# 0  K0   A0   B0  NaN
# 1  K1   A1   B1  NaN
# 2  K2   A2   B2  NaN
# 3  K3   A3   B3  NaN
# 4  K0  A10  NaN  B10
# 5  K1  A11  NaN  B11
# 6  K4  A12  NaN  B12
# 7  K5  A13  NaN  B13

# %%
pd.merge(left, right, on='key')
# Out:
#   key A_x   B  A_y    D
# 0  K0  A0  B0  A10  B10
# 1  K1  A1  B1  A11  B11

# %%
pd.merge(left, right, on='key',suffixes=('_left','_right'))
# Out:
#   key A_left   B A_right    D
# 0  K0     A0  B0     A10  B10
# 1  K1     A1  B1     A11  B11
